# %% [markdown]
# ### 각 지역별 응급실 현황 데이터 살펴보기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 전체 코드 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
emergency_room = pd.read_csv('../[0]data/6_시도별_요양기관_현황_2019.csv', encoding='euc-kr')
emergency_room.info()
emergency_room.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시도별(1)   19 non-null     object
#  1   2019     19 non-null     object
#  2   2019.1   19 non-null     object
#  3   2019.2   19 non-null     object
#  4   2019.3   19 non-null     object
#  5   2019.4   19 non-null     object
#  6   2019.5   19 non-null     object
#  7   2019.6   19 non-null     object
#  8   2019.7   19 non-null     object
#  9   2019.8   19 non-null     object
#  10  2019.9   19 non-null     object
#  11  2019.10  19 non-null     object
#  12  2019.11  19 non-null     object
#  13  2019.12  19 non-null     object
#  14  2019.13  19 non-null     object
#  15  2019.14  19 non-null     object
#  16  2019.15  19 non-null     object
# dtypes: object(17)
# memory usage: 2.6+ KB
#    시도별(1)   2019  2019.1 2019.2 2019.3 2019.4 2019.5 2019.6 2019.7 2019.8  \
# ...

# %%
emergency_room.columns = emergency_room.iloc[0]
emergency_room
# Out:
# 0   시도별(1)      계  상급종합병원  종합병원    병원  요양병원     의원  치과병원   치과의원  한방병원    한의원  \
# 0   시도별(1)      계  상급종합병원  종합병원    병원  요양병원     의원  치과병원   치과의원  한방병원    한의원
# 1        계  94865      42   314  1489  1577  32491   239  17963   352  14408
# 2       서울  22739      13    44   228   124   8628    65   4836    53   3617
# 3       부산   6752       4    25   142   190   2384    24   1273    10   1136
# 4       대구   5083       5    11   109    69   1803    16    883     3    878
# 5       인천   4497       3    16    62    71   1573     9    911    33    658
# 6       광주   2852       2    21    80    66    948    14    625    85    323
# 7       대전   2984       1     9    51    50   1078     6    530     7    505
# 8       울산   1801       -     8    43    42    609     4    383     3    275
# 9       세종    491       -     1     -     6    181     1     85     1     76
# 10      경기  20491       5    59   277   345   7065    37   4204    65   3146
# ...

# %%
emergency_room.replace('-','0',inplace=True)

# %%
emergency_room
# Out:
# 0   시도별(1)      계  상급종합병원  종합병원    병원  요양병원     의원  치과병원   치과의원  한방병원    한의원  \
# 0   시도별(1)      계  상급종합병원  종합병원    병원  요양병원     의원  치과병원   치과의원  한방병원    한의원
# 1        계  94865      42   314  1489  1577  32491   239  17963   352  14408
# 2       서울  22739      13    44   228   124   8628    65   4836    53   3617
# 3       부산   6752       4    25   142   190   2384    24   1273    10   1136
# 4       대구   5083       5    11   109    69   1803    16    883     3    878
# 5       인천   4497       3    16    62    71   1573     9    911    33    658
# 6       광주   2852       2    21    80    66    948    14    625    85    323
# 7       대전   2984       1     9    51    50   1078     6    530     7    505
# 8       울산   1801       0     8    43    42    609     4    383     3    275
# 9       세종    491       0     1     0     6    181     1     85     1     76
# 10      경기  20491       5    59   277   345   7065    37   4204    65   3146
# ...

# %%
emergency_room.drop([0,1],inplace=True)

# %%
emergency_room
# Out:
# 0  시도별(1)      계 상급종합병원 종합병원   병원 요양병원    의원 치과병원  치과의원 한방병원   한의원 보건소 보건지소  \
# 2      서울  22739     13   44  228  124  8628   65  4836   53  3617  25    8
# 3      부산   6752      4   25  142  190  2384   24  1273   10  1136  16   11
# 4      대구   5083      5   11  109   69  1803   16   883    3   878   8    9
# 5      인천   4497      3   16   62   71  1573    9   911   33   658  10   27
# 6      광주   2852      2   21   80   66   948   14   625   85   323   5    1
# 7      대전   2984      1    9   51   50  1078    6   530    7   505   5    6
# 8      울산   1801      0    8   43   42   609    4   383    3   275   5    8
# 9      세종    491      0    1    0    6   181    1    85    1    76   1   10
# 10     경기  20491      5   59  277  345  7065   37  4204   65  3146  45  124
# 11     강원   2519      1   14   45   32   769    4   388    1   362  16   97
# 12     충북   2769      1   12   37   49   891    4   431    7   403  14   95
# ...

# %%
emergency_room.index = emergency_room['시도별(1)']
del emergency_room['시도별(1)']

# %%
emergency_room
# Out:
# 0           계 상급종합병원 종합병원   병원 요양병원    의원 치과병원  치과의원 한방병원   한의원 보건소 보건지소  \
# 시도별(1)
# 서울      22739     13   44  228  124  8628   65  4836   53  3617  25    8
# 부산       6752      4   25  142  190  2384   24  1273   10  1136  16   11
# 대구       5083      5   11  109   69  1803   16   883    3   878   8    9
# 인천       4497      3   16   62   71  1573    9   911   33   658  10   27
# 광주       2852      2   21   80   66   948   14   625   85   323   5    1
# 대전       2984      1    9   51   50  1078    6   530    7   505   5    6
# 울산       1801      0    8   43   42   609    4   383    3   275   5    8
# 세종        491      0    1    0    6   181    1    85    1    76   1   10
# 경기      20491      5   59  277  345  7065   37  4204   65  3146  45  124
# 강원       2519      1   14   45   32   769    4   388    1   362  16   97
# 충북       2769      1   12   37   49   891    4   431    7   403  14   95
# 충남       3641      2   11   44   88  1074   11   560   11   517  14  151
# ...

# %%
emergency_room=emergency_room[['상급종합병원','종합병원']]

# %%
emergency_room
# Out:
# 0      상급종합병원 종합병원
# 시도별(1)
# 서울         13   44
# 부산          4   25
# 대구          5   11
# 인천          3   16
# 광주          2   21
# 대전          1    9
# 울산          0    8
# 세종          0    1
# 경기          5   59
# 강원          1   14
# 충북          1   12
# 충남          2   11
# 전북          2   11
# 전남          1   22
# 경북          0   20
# 경남          2   24
# 제주          0    6

# %%
emergency_room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 서울 to 제주
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상급종합병원  17 non-null     object
#  1   종합병원    17 non-null     object
# dtypes: object(2)
# memory usage: 408.0+ bytes

# %%
emergency_room
# Out:
# 0      상급종합병원 종합병원
# 시도별(1)
# 서울         13   44
# 부산          4   25
# 대구          5   11
# 인천          3   16
# 광주          2   21
# 대전          1    9
# 울산          0    8
# 세종          0    1
# 경기          5   59
# 강원          1   14
# 충북          1   12
# 충남          2   11
# 전북          2   11
# 전남          1   22
# 경북          0   20
# 경남          2   24
# 제주          0    6

# %%
emergency_room = emergency_room.loc[['제주','전남','충남']]

# %%
# emergency_room = emergency_room.loc[['제주','전남','충남']]
emergency_room
# Out:
# 0      상급종합병원 종합병원
# 시도별(1)
# 제주          0    6
# 전남          1   22
# 충남          2   11

# %%
emergency_room = emergency_room.astype('int')
emergency_room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 제주 to 충남
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상급종합병원  3 non-null      int64
#  1   종합병원    3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes

# %%
emergency_room['응급실 현황'] = emergency_room['상급종합병원'] + emergency_room['종합병원']

# %%
emergency_room.index.name='시/도'

# %%
emergency_room.sort_values(by="응급실 현황",inplace=True)

# %%
# plt.plot(emergency_room)

# %%
emergency_room.to_csv('../[0]data/0-4_시도별_응급실_현황(결과).csv')

# %%
plt.figure(figsize=(10,10))
emergency_room["응급실 현황"].plot(kind='bar',grid=True,rot=0,color='yellowgreen',alpha=0.7)
plt.title("<제주,충남,전남 응급실 현황>")
# Out:
# <AxesSubplot:xlabel='시/도'>
# Text(0.5, 1.0, '<제주,충남,전남 응급실 현황>')

# %%
# 결과 : 
# 응급실을 갖춘 병원의 수가 '전남','충남','제주'순으로 나타남 
#  사고다발지역과 함께 연관을 지어서 gecode로 표시할 예정

# %%
# plt.figure(figsize=(20,10))

# x = range(0,len(emergency_room.columns))
# y1 = emergency_room.T['제주'].values
# y2 = emergency_room.T['전남'].values
# y3 = emergency_room.T['충남'].values

# plt.bar(emergency_room.T.index,emergency_room.T['제주'],label='제주')
# plt.xticks(emergency_room.columns)
# for i, v in enumerate(x):
#     plt.text(v, y1[i], y1[i],                 
#              fontsize = 15, 
#              color='blue',
#              horizontalalignment='center',
#              verticalalignment='bottom')


# plt.bar(emergency_room.T.index,emergency_room.T['전남'],alpha=0.4,label='전남')
# plt.xticks(emergency_room.columns)
# for i, v in enumerate(x):
#     plt.text(v, y2[i], y2[i],                 
#              fontsize = 15, 
#              color='blue',
#              horizontalalignment='center',
#              verticalalignment='bottom')

# plt.bar(emergency_room.T.index,emergency_room.T['충남'],alpha=0.2,label='충남')
# plt.xticks(emergency_room.columns)
# for i, v in enumerate(x):
#     plt.text(v, y3[i], y3[i],                 
#              fontsize = 15, 
#              color='blue',
#              horizontalalignment='center',
#              verticalalignment='bottom')
    

# prop = dict(
#     size=15 # 글씨 크기
# )
 
# config_legend = dict( ## 범례 설정
#     loc = 'upper left', # 범례 위치 설정
#     prop=prop # 범례 폰트 속성
# )

# plt.legend(**config_legend)
# plt.show()
